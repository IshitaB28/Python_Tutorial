# %% [markdown]
# # PANDAS

# %%
import pandas as pd

# %%
df=pd.read_csv('ex1.csv')

# %%
df
# Out:
#    a   b   c   d meassage
# 0  1   2   3   4    hello
# 1  5   6   7   8    world
# 2  9  10  11  12      foo

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Data frame means tabular structure. Separated with the delimeter.

# %%
df.head() # shows first 5 rows
# Out:
#    a   b   c   d meassage
# 0  1   2   3   4    hello
# 1  5   6   7   8    world
# 2  9  10  11  12      foo

# %%
df.head(2)
# Out:
#    a  b  c  d meassage
# 0  1  2  3  4    hello
# 1  5  6  7  8    world

# %%
df.tail(2) # last two data
# Out:
#    a   b   c   d meassage
# 1  5   6   7   8    world
# 2  9  10  11  12      foo

# %%
df.head(-2)
# Out:
#    a  b  c  d meassage
# 0  1  2  3  4    hello

# %%
df.dtypes   # this shows the different types of datatypes
# Out:
# a            int64
# b            int64
# c            int64
# d            int64
# meassage    object
# dtype: object

# %%
df['d']
# Out:
# 0     4
# 1     8
# 2    12
# Name: d, dtype: int64

# %%
type(df['d'])   # series is equivalent to a list but in order to convert into list we need to use functions
# Out:
# pandas.core.series.Series

# %% [markdown]
# If we access series, it will also give the index along with the data. We can also manipulate the indexes. ALl this is not possible in a list.

# %%
list(df['d'])   # gets converted into the list
# Out:
# [4, 8, 12]

# %%
df[['d']]
# Out:
#     d
# 0   4
# 1   8
# 2  12

# %%
type(df[['d']]) # this gives a dataframe. Changes into the frame strcuture
# Out:
# pandas.core.frame.DataFrame

# %%
df['d', 'a']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('d', 'a')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-af68e51ffdcd> in <module>
# ----> 1 df['d', 'a']
#
# ...

# %%
df[['d', 'a']]
# Out:
#     d  a
# 0   4  1
# 1   8  5
# 2  12  9

# %%
df=pd.read_csv('ex1.csv', header=None)  # if we donot want to consider first row as the column names

# %%
df.head()
# Out:
#    0   1   2   3         4
# 0  a   b   c   d  meassage
# 1  1   2   3   4     hello
# 2  5   6   7   8     world
# 3  9  10  11  12       foo

# %%
df1=pd.read_table('ex2.tsv')

# %%
df1.head()
# Out:
#   test test.1 test.2 test.3 test.4
# 0  ish    ish    ish    ish    ish
# 1   py     py     py     py     py

# %%
df1=pd.read_table('ex2.tsv', header=None)

# %%
df1.head()
# Out:
#       0     1     2     3     4
# 0  test  test  test  test  test
# 1   ish   ish   ish   ish   ish
# 2    py    py    py    py    py

# %%
pd.read_csv('ex2.tsv')
# Out:
#   test\ttest\ttest\ttest\ttest
# 0      ish\tish\tish\tish\tish
# 1           py\tpy\tpy\tpy\tpy

# %%
pd.read_csv('ex2.tsv', sep='\t')
# Out:
#   test test.1 test.2 test.3 test.4
# 0  ish    ish    ish    ish    ish
# 1   py     py     py     py     py

# %%
df=pd.read_csv('ex1.csv', header=None, names=['p', 'q', 'r', 's', 't'])

# %%
df.head()
# Out:
#    p   q   r   s         t
# 0  a   b   c   d  meassage
# 1  1   2   3   4     hello
# 2  5   6   7   8     world
# 3  9  10  11  12       foo

# %%
df=pd.read_csv('ex1.csv', header=None, names=['p', 'q', 'r', 's', 't', 'x'])
df.head()
# Out:
#    p   q   r   s         t   x
# 0  a   b   c   d  meassage NaN
# 1  1   2   3   4     hello NaN
# 2  5   6   7   8     world NaN
# 3  9  10  11  12       foo NaN

# %%
df=pd.read_csv('ex1.csv', header=None, names=['p', 'q', 'r'])

# %%
df.head()
# Out:
#        p   q         r
# a b    c   d  meassage
# 1 2    3   4     hello
# 5 6    7   8     world
# 9 10  11  12       foo

# %%
df=pd.read_csv('csv_indexes.csv')
df.head()
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  two    c       5       6

# %%
df=pd.read_csv('csv_indexes.csv', index_col=['key1'])
df.head()
# Out:
#      key2  value1  value2
# key1
# one     a       1       2
# one     b       3       4
# two     c       5       6

# %%
df=pd.read_csv('csv_indexes.csv', index_col=['key1', 'key2'])
df.head()
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
# two  c          5       6

# %%
pd.read_csv('esx2.csv')
# Out:
#                                  #hey
# a                b   c   d    message
# #difficult there NaN NaN NaN      NaN
# #who csv vfi les NaN NaN NaN      NaN
# 1                2   3   4      hello
# 5                6   7   8      world
# 9                10  11  12       foo

# %%
pd.read_csv('esx2.csv', skiprows=[0,2,3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df1=pd.read_csv('ex1.csv', header=None, names=['p', 'q', 'r', 's', 't', 'x'])
df1.head()
# Out:
#    p   q   r   s         t   x
# 0  a   b   c   d  meassage NaN
# 1  1   2   3   4     hello NaN
# 2  5   6   7   8     world NaN
# 3  9  10  11  12       foo NaN

# %%
df=pd.read_csv('ex1.csv', header=None, names=['p', 'q', 'r', 's', 't', 'x'], na_values=['1'])
df.head()
# Out:
#      p   q   r   s         t   x
# 0    a   b   c   d  meassage NaN
# 1  NaN   2   3   4     hello NaN
# 2    5   6   7   8     world NaN
# 3    9  10  11  12       foo NaN

# %%
pd.read_excel('Monthly Sales.xlsx')
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 4706   19645           High      0.02      107.53           5.81         1748
# 4707   19693           High      0.10       35.99           5.00         1748
# 4708   19696         Medium      0.10        2.88           0.50         1748
# 4709   20571  Not Specified      0.02        4.13           6.89         1749
# 4710   19863            Low      0.04       60.65          12.23         1749
#
# ...

# %% [markdown]
# If the dataset is not in this folder, put the location while reading.
# in case you get a unicode error write:   pd.read_excel(r'Monthly Sales.xlsx') or put \\ instead of / in the location

# %%
pd.read_excel(r'Monthly Sales.xlsx')
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 4706   19645           High      0.02      107.53           5.81         1748
# 4707   19693           High      0.10       35.99           5.00         1748
# 4708   19696         Medium      0.10        2.88           0.50         1748
# 4709   20571  Not Specified      0.02        4.13           6.89         1749
# 4710   19863            Low      0.04       60.65          12.23         1749
#
# ...

# %%
df2=pd.read_excel('Monthly Sales.xlsx', sheet_name='Student')
df2.head()
# Out:
#    id   Fname  Lname Course
# 0   1     Ram    dan   Math
# 1   2    sham    can   Math
# 2   3   kamal   raja   Math
# 3  10  wiliam  kumar    Eng
# 4  12     san    don    Eng

# %%
df2.tail()
# Out:
#    id   Fname  Lname Course
# 0   1     Ram    dan   Math
# 1   2    sham    can   Math
# 2   3   kamal   raja   Math
# 3  10  wiliam  kumar    Eng
# 4  12     san    don    Eng

# %%
df2['id']
# Out:
# 0     1
# 1     2
# 2     3
# 3    10
# 4    12
# Name: id, dtype: int64

# %%
df2[['id']]
# Out:
#    id
# 0   1
# 1   2
# 2   3
# 3  10
# 4  12

# %%
df2=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df2)
# Out:
# list

# %%
len(df2)
# Out:
# 1

# %%
df2[0]    # the dataframes/tables are stored in the form of a list
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df2[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df2[0].head(6)
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
# 5  5  Arron Afflalo  SG  29  DEN  53  53  1750  281  657  ...  .841   21  159
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
# 5  180  101  32   5   83  108   771
#
# [6 rows x 30 columns]

# %%
df2[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv')
df3.head()
# Out:
#                    PassengerId\tSurvived\tPclass\tName\tSex\tAge\tSibSp\tParch\tTicket\tFare\tCabin\tEmbarked
# 1\t0\t3\tBraund      Mr. Owen Harris\tmale\t22\t1\t0\tA/5 21171\t7...
# 2\t1\t1\tCumings     Mrs. John Bradley (Florence Briggs Thayer)\tf...
# 3\t1\t3\tHeikkinen   Miss. Laina\tfemale\t26\t0\t0\tSTON/O2. 31012...
# 4\t1\t1\tFutrelle    Mrs. Jacques Heath (Lily May Peel)\tfemale\t3...
# 5\t0\t3\tAllen       Mr. William Henry\tmale\t35\t0\t0\t373450\t8....

# %%
df3=pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv', sep='\t')
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df3.tail()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
df3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df3[['Pclass', 'Sex', 'Age']]
# Out:
#      Pclass     Sex   Age
# 0         3    male  22.0
# 1         1  female  38.0
# 2         3  female  26.0
# 3         1  female  35.0
# 4         3    male  35.0
# ..      ...     ...   ...
# 151       1  female  22.0
# 152       3    male  55.5
# 153       3    male  40.5
# 154       3    male   NaN
# 155       1    male  51.0
#
# [156 rows x 3 columns]

# %%
df=pd.read_csv('ex1.csv', nrows=2)   # it will not load any other record. It will read only the first 2 rows

# %%
df.head(2)
# Out:
#    a  b  c  d meassage
# 0  1  2  3  4    hello
# 1  5  6  7  8    world

# %%
df=pd.read_csv('ex1.csv', chunksize=300)  # it will extract only 300 bytes of the data

# %%
df

# %%
df3.to_csv('titanicdata.csv')   # save data permanently. without re esecuting

# %%
df3.to_csv('titanicdatatab.csv', sep='\t')

# %%
df3.to_csv('titanic.csv', index=False)  # we can also give our own column names

# %%
a=pd.read_csv('ex1.csv')
a.to_pickle("testpick")   # this is a binary file. writes in the byte code format


# object to byte code::    SERIALIZATION
# byte code to object::    DESERIALIZATION


# tHis operation is called a Serde operatuion

# %%
b=pd.read_pickle('testpick')
b
# Out:
#    a   b   c   d meassage
# 0  1   2   3   4    hello
# 1  5   6   7   8    world
# 2  9  10  11  12      foo
